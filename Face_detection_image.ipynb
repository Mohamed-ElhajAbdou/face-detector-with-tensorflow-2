# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from scipy import misc
import cv2
import numpy as np
import facenet
import detect_face
import os
import time
import pickle
import sys

img_path='abc.jpg'
modeldir = './model/20170511-185253.pb'
classifier_filename = './class/classifier.pkl'
npy='./npy'
train_img="./train_img"

with tf.Graph().as_default():
    gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.6)
    sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options, log_device_placement=False))
    with sess.as_default():
        pnet, rnet, onet = detect_face.create_mtcnn(sess, npy)

        minsize = 20  # minimum size of face
        threshold = [0.6, 0.7, 0.7]  # three steps's threshold
        factor = 0.709  # scale factor
        margin = 44
        frame_interval = 3
        batch_size = 1000
        image_size = 182
        input_image_size = 160
        
        HumanNames = os.listdir(train_img)
        HumanNames.sort()

        print('Loading feature extraction model')
        facenet.load_model(modeldir)

        images_placeholder = tf.compat.v1.get_default_graph().get_tensor_by_name("input:0")
        embeddings = tf.compat.v1.get_default_graph().get_tensor_by_name("embeddings:0")
        phase_train_placeholder = tf.compat.v1.get_default_graph().get_tensor_by_name("phase_train:0")
        embedding_size = embeddings.get_shape()[1]


        classifier_filename_exp = os.path.expanduser(classifier_filename)
        with open(classifier_filename_exp, 'rb') as infile:
            (model, class_names) = pickle.load(infile)

        # video_capture = cv2.VideoCapture("akshay_mov.mp4")
        c = 0


        print('Start Recognition!')
        prevTime = 0
        # ret, frame = video_capture.read()
        frame = cv2.imread(img_path,0)

        frame = cv2.resize(frame, (0,0), fx=0.5, fy=0.5)    #resize frame (optional)

        curTime = time.time()+1    # calc fps
        timeF = frame_interval

        if (c % timeF == 0):
            find_results = []

            if frame.ndim == 2:
                frame = facenet.to_rgb(frame)
            frame = frame[:, :, 0:3]
            bounding_boxes, _ = detect_face.detect_face(frame, minsize, pnet, rnet, onet, threshold, factor)
            nrof_faces = bounding_boxes.shape[0]
            print('Face Detected: %d' % nrof_faces)

            if nrof_faces > 0:
                det = bounding_boxes[:, 0:4]
                img_size = np.asarray(frame.shape)[0:2]

                cropped = []
                scaled = []
                scaled_reshape = []
                bb = np.zeros((nrof_faces,4), dtype=np.int32)

                for i in range(nrof_faces):
                    emb_array = np.zeros((1, embedding_size))

                    bb[i][0] = det[i][0]
                    bb[i][1] = det[i][1]
                    bb[i][2] = det[i][2]
                    bb[i][3] = det[i][3]

                    # inner exception
                    if bb[i][0] <= 0 or bb[i][1] <= 0 or bb[i][2] >= len(frame[0]) or bb[i][3] >= len(frame):
                        print('face is too close')
                        continue

                    cropped.append(frame[bb[i][1]:bb[i][3], bb[i][0]:bb[i][2], :])
                    cropped[i] = facenet.flip(cropped[i], False)
                    scaled.append(misc.imresize(cropped[i], (image_size, image_size), interp='bilinear'))
                    scaled[i] = cv2.resize(scaled[i], (input_image_size,input_image_size),
                                           interpolation=cv2.INTER_CUBIC)
                    scaled[i] = facenet.prewhiten(scaled[i])
                    scaled_reshape.append(scaled[i].reshape(-1,input_image_size,input_image_size,3))
                    feed_dict = {images_placeholder: scaled_reshape[i], phase_train_placeholder: False}
                    emb_array[0, :] = sess.run(embeddings, feed_dict=feed_dict)
                    predictions = model.predict_proba(emb_array)
                    print(predictions)
                    best_class_indices = np.argmax(predictions, axis=1)
                    # print(best_class_indices)
                    best_class_probabilities = predictions[np.arange(len(best_class_indices)), best_class_indices]
                    print(best_class_probabilities)
                    cv2.rectangle(frame, (bb[i][0], bb[i][1]), (bb[i][2], bb[i][3]), (0, 255, 0), 2)    #boxing face

                    #plot result idx under box
                    text_x = bb[i][0]
                    text_y = bb[i][3] + 20
                    print('Result Indices: ', best_class_indices[0])
                    print(HumanNames)
                    for H_i in HumanNames:
                        # print(H_i)
                        if HumanNames[best_class_indices[0]] == H_i:
                            result_names = HumanNames[best_class_indices[0]]
                            cv2.putText(frame, result_names, (text_x, text_y), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                                        1, (0, 0, 255), thickness=1, lineType=2)
            else:
                print('Unable to align')
        cv2.imshow('Image', frame)

        if cv2.waitKey(1000000) & 0xFF == ord('q'):
            sys.exit("Thanks")
        cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0821aadc2942> in <module>()
#      23     sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options, log_device_placement=False))
#      24     with sess.as_default():
# ---> 25         pnet, rnet, onet = detect_face.create_mtcnn(sess, npy)
#      26
#      27         minsize = 20  # minimum size of face
#
# ~\tensorflow\Facenet-Real-time-face-recognition-using-deep-learning-Tensorflow2\detect_face.py in create_mtcnn(sess, model_path)
#     291         data = tf.compat.v1.placeholder(tf.float32, (None,None,None,3), 'input')
#     292         pnet = PNet({'data':data})
# --> 293         pnet.load(os.path.join(model_path, 'det1.npy'), sess)
#     294     with tf.compat.v1.variable_scope('rnet'):
#     295         data = tf.compat.v1.placeholder(tf.float32, (None,24,24,3), 'input')
#
# ~\tensorflow\Facenet-Real-time-face-recognition-using-deep-learning-Tensorflow2\detect_face.py in load(self, data_path, session, ignore_missing)
#      83         ignore_missing: If true, serialized weights for missing layers are ignored.
#      84         '''
# ---> 85         data_dict = np.load(data_path, encoding='latin1',allow_pickle=True).item() #pylint: disable=no-member
#      86
#      87         for op_name in data_dict:
#
# ~\AppData\Roaming\Python\Python36\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     451             else:
#     452                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 453                                          pickle_kwargs=pickle_kwargs)
#     454         else:
#     455             # Try a pickle
#
# ~\AppData\Roaming\Python\Python36\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     720         # The array contained Python objects. We need to unpickle the data.
#     721         if not allow_pickle:
# --> 722             raise ValueError("Object arrays cannot be loaded when "
#     723                              "allow_pickle=False")
#     724         if pickle_kwargs is None:
#
# ValueError: Object arrays cannot be loaded when allow_pickle=False

# %%
import numpy 
numpy.version.version
# Out:
# '1.17.3'

# %%
import cv2

# %%
from tensorflow.python.framework import ops

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# W1025 17:56:49.477663 13364 warnings.py:99] C:\Users\Mohamed\Anaconda_3_v_1\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
#
# WARNING: AstropyDeprecationWarning: The astropy.vo.samp module has now been moved to astropy.samp [astropy.vo.samp]
# W1025 17:56:55.493826 13364 logger.py:220] AstropyDeprecationWarning: The astropy.vo.samp module has now been moved to astropy.samp
# W1025 17:57:01.334947 13364 logger.py:177] C:\Users\Mohamed\Anaconda_3_v_1\lib\site-packages\odo\backends\pandas.py:102: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))
#
# W1025 17:57:18.523508 13364 logger.py:177] C:\Users\Mohamed\Anaconda_3_v_1\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
#
# W1025 17:57:23.423712 13364 logger.py:177] C:\Users\Mohamed\Anaconda_3_v_1\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
#
# W1025 17:57:25.443486 13364 logger.py:177] C:\Users\Mohamed\Anaconda_3_v_1\lib\site-packages\qtawesome\iconic_font.py:268: UserWarning: You need to have a running QApplication to use QtAwesome!
#   warnings.warn("You need to have a running "
#
# W1025 17:57:26.693679 13364 logger.py:177] C:\Users\Mohamed\Anaconda_3_v_1\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# _cffi_ext.c
# C:\Users\Mohamed\Anaconda_3_v_1\include\pyconfig.h(59): fatal error C1083: Cannot open include file: 'io.h': No such file or directory
# Crypto              cgi                 mistune             spyder_profiler
# Cython              cgitb               mkl                 spyder_pylint
# IPython             chardet             mkl_fft             sqlalchemy
# OpenSSL             chunk               mkl_random          sqlite3
# PIL                 classifier          mmap                sre_compile
# PyQt5               click               mmapfile            sre_constants
# __future__          cloudpickle         mmsystem            sre_parse
# _ast                clyent              modulefinder        ssl
# _asyncio            cmath               more_itertools      sspi
# _bisect             cmd                 mpmath              sspicon
# _blake2             code                msgpack             stat
# _bootlocale         codecov             msilib              statistics
# _bz2                codecs              msvcrt              statsmodels
# _cffi_backend       codeop              multipledispatch    storemagic
# _codecs             collections         multiprocessing     string
# _codecs_cn          colorama            navigator_updater   stringprep
# _codecs_hk          colorsys            nbconvert           struct
# _codecs_iso2022     commctrl            nbformat            subprocess
# _codecs_jp          compileall          netbios             sunau
# _codecs_kr          comtypes            netrc               symbol
# _codecs_tw          concurrent          networkx            sympy
# _collections        conda               nltk                sympyprinting
# _collections_abc    conda_build         nntplib             symtable
# _compat_pickle      conda_env           nose                sys
# _compression        conda_verify        notebook            sysconfig
# _csv                configparser        nt                  tables
# _ctypes             contextlib          ntpath              tabnanny
# _ctypes_test        contextlib2         ntsecuritycon       tarfile
# _datetime           copy                nturl2path          tblib
# _decimal            copyreg             numbers             telnetlib
# _dummy_thread       coverage            numexpr             tempfile
# _elementtree        crypt               numpy               tensorboard
# _findvs             cryptography        numpydoc            tensorflow
# _functools          csv                 odbc                tensorflow_estimator
# _hashlib            ctypes              odo                 termcolor
# _heapq              curl                olefile             terminado
# _imp                curses              opcode              test
# _io                 cv2                 openpyxl            test_path
# _json               cwp                 operator            test_pycosat
# _locale             cycler              opt_einsum          testpath
# _lsprof             cython              optparse            tests
# _lzma               cythonmagic         os                  textwrap
# _markupbase         cytoolz             packaging           this
# _md5                dask                pandas              threading
# _msi                data_preprocess     pandocfilters       time
# _multibytecodec     datashape           parser              timeit
# _multiprocessing    datetime            parso               timer
# _nsis               dateutil            partd               tkinter
# _opcode             dbi                 pasta               tlz
# _operator           dbm                 path                token
# _osx_support        dde                 pathlib             tokenize
# _overlapped         decimal             pathlib2            toolz
# _pickle             decorator           patsy               tornado
# _pydecimal          detect_face         pdb                 trace
# _pyio               difflib             pep8                traceback
# _pytest             dis                 perfmon             tracemalloc
# _random             distributed         pickle              train_main
# _sha1               distutils           pickleshare         traitlets
# _sha256             doctest             pickletools         tty
# _sha3               docutils            pip                 turtle
# _sha512             dummy_threading     pipes               turtledemo
# _signal             easy_install        pkg_resources       types
# _sitebuiltins       email               pkginfo             typing
# _socket             encodings           pkgutil             unicodecsv
# _sqlite3            ensurepip           platform            unicodedata
# _sre                entrypoints         plistlib            unittest
# _ssl                enum                pluggy              urllib
# _stat               errno               ply                 urllib3
# _string             et_xmlfile          poplib              uu
# _strptime           facenet             posixpath           uuid
# _struct             fastcache           pprint              venv
# _symtable           faulthandler        preprocess          warnings
# _system_path        filecmp             profile             wave
# _testbuffer         fileinput           prompt_toolkit      wcwidth
# _testcapi           filelock            pstats              weakref
# _testconsole        flask               psutil              webbrowser
# _testimportmultiple flask_cors          pty                 webencodings
# _testmultiphase     fnmatch             py                  werkzeug
# _thread             formatter           py_compile          wheel
# _threading_local    fractions           pyclbr              widgetsnbextension
# _tkinter            ftplib              pycodestyle         win2kras
# _tracemalloc        functools           pycosat             win32api
# _warnings           gast                pycparser           win32clipboard
# _weakref            gc                  pycurl              win32com
# _weakrefset         genericpath         pydoc               win32con
# _win32sysloader     getopt              pydoc_data          win32console
# _winapi             getpass             pyexpat             win32cred
# _winxptheme         gettext             pyflakes            win32crypt
# _yaml               gevent              pygments            win32cryptcon
# abc                 glob                pylab               win32event
# absl                glob2               pylint              win32evtlog
# adodbapi            greenlet            pyodbc              win32evtlogutil
# afxres              grpc                pyparsing           win32file
# aifc                gzip                pytest              win32gui
# alabaster           h5py                pytest_cov          win32gui_struct
# anaconda_navigator  hashlib             pythoncom           win32help
# anaconda_project    heapdict            pytz                win32inet
# antigravity         heapq               pywin               win32inetcon
# argparse            hmac                pywin32_testutil    win32job
# array               html                pywintypes          win32lz
# asn1crypto          html5lib            pywt                win32net
# ast                 http                pyximport           win32netcon
# astor               identify_face_image qtawesome           win32pdh
# astroid             identify_face_video qtconsole           win32pdhquery
# astropy             idlelib             qtpy                win32pdhutil
# asynchat            idna                queue               win32pipe
# asyncio             imageio             quopri              win32print
# asyncore            imagesize           random              win32process
# atexit              imaplib             rasutil             win32profile
# atomicwrites        imghdr              re                  win32ras
# attr                imp                 regcheck            win32rcparser
# audioop             importlib           regutil             win32security
# autoreload          importlib_metadata  reprlib             win32service
# babel               inspect             requests            win32serviceutil
# backports           io                  rlcompleter         win32timezone
# base64              ipaddress           rmagic              win32trace
# bdb                 ipykernel           rope                win32traceutil
# binascii            ipykernel_launcher  ruamel_yaml         win32transaction
# binhex              ipython_genutils    run                 win32ts
# binstar_client      ipywidgets          runpy               win32ui
# bisect              isapi               sched               win32uiole
# bitarray            isort               scipy               win32verstamp
# bkcharts            itertools           scripts             win32wnet
# blaze               itsdangerous        seaborn             win_inet_pton
# bleach              jdcal               secrets             win_unicode_console
# bokeh               jedi                select              wincertstore
# boto                jinja2              selectors           winerror
# bottleneck          joblib              send2trash          winioctlcon
# brain_attrs         json                servicemanager      winnt
# brain_builtin_inference jsonschema          setuptools          winperf
# brain_collections   jupyter             shelve              winpty
# brain_curses        jupyter_client      shlex               winreg
# brain_dateutil      jupyter_console     shutil              winsound
# brain_fstrings      jupyter_core        signal              winxpgui
# brain_functools     jupyterlab          simplegeneric       winxptheme
# brain_gi            jupyterlab_launcher singledispatch      wrapt
# brain_hashlib       keras_applications  singledispatch_helpers wsgiref
# brain_io            keras_preprocessing sip                 xdrlib
# brain_mechanize     keyword             sipconfig           xlrd
# brain_multiprocessing lazy_object_proxy   sipdistutils        xlsxwriter
# brain_namedtuple_enum lib2to3             site                xlwings
# brain_nose          linecache           six                 xlwt
# brain_numpy         llvmlite            skimage             xml
# brain_pkg_resources locale              sklearn             xmlrpc
# brain_pytest        locket              smtpd               xxsubtype
# brain_qt            logging             smtplib             yaml
# brain_re            lxml                sndhdr              zict
# brain_six           lzma                snowballstemmer     zipapp
# brain_ssl           macpath             socket              zipfile
# brain_subprocess    macurl2path         socketserver        zipimport
# brain_threading     mailbox             socks               zipp
# brain_typing        mailcap             sockshandler        zlib
# brain_uuid          markdown            sortedcollections   zmq
# bs4                 markupsafe          sortedcontainers    ~-nsorflow_core
# builtins            marshal             sphinx              ~ensorflow_core
# bz2                 math                sphinxcontrib       ~ip
# cProfile            matplotlib          spyder              ~umpy
# calendar            mccabe              spyder_breakpoints  ~~nsorflow_core
# certifi             menuinst            spyder_io_dcm
# cffi                mimetypes           spyder_io_hdf5
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
import torch
print(torch)
# Out:
# <module 'torch' from 'C:\\Users\\Mohamed\\Anaconda_3_v_1\\lib\\site-packages\\torch\\__init__.py'>
